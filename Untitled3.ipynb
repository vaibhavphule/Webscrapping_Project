# %%
import datetime

x = datetime.datetime.now()
print(x)
# Out:
# 2021-05-04 15:05:30.681337

# %%
import datetime

x = datetime.date(2020, 5, 17)

print(x)
# Out:
# 2020-05-17

# %%
for i in range (1,6):
    if i==1:
        for j in range(14,32):
             print(f"https://www.delhisldc.org/Loaddata.aspx?mode={j}/01/2021")
    elif i==2:
        for j in range(1,29):
            if j>10:
                print(f"https://www.delhisldc.org/Loaddata.aspx?mode={j}/0{i}/2021")
            else:
                print(f"https://www.delhisldc.org/Loaddata.aspx?mode=0{j}/0{i}/2021")
    elif i==3:
        for j in range(1,32):
            if j>10:
                print(f"https://www.delhisldc.org/Loaddata.aspx?mode={j}/0{i}/2021")
            else:
                print(f"https://www.delhisldc.org/Loaddata.aspx?mode=0{j}/0{i}/2021")
    elif i==4:
         for j in range(1,31):
            if j>10:
                print(f"https://www.delhisldc.org/Loaddata.aspx?mode={j}/0{i}/2021")
            else:
                print(f"https://www.delhisldc.org/Loaddata.aspx?mode=0{j}/0{i}/2021")
    else:
        for j in range(1,4):
             print(f"https://www.delhisldc.org/Loaddata.aspx?mode=0{j}/0{i}/2021")
# Out:
# https://www.delhisldc.org/Loaddata.aspx?mode=14/01/2021
# https://www.delhisldc.org/Loaddata.aspx?mode=15/01/2021
# https://www.delhisldc.org/Loaddata.aspx?mode=16/01/2021
# https://www.delhisldc.org/Loaddata.aspx?mode=17/01/2021
# https://www.delhisldc.org/Loaddata.aspx?mode=18/01/2021
# https://www.delhisldc.org/Loaddata.aspx?mode=19/01/2021
# https://www.delhisldc.org/Loaddata.aspx?mode=20/01/2021
# https://www.delhisldc.org/Loaddata.aspx?mode=21/01/2021
# https://www.delhisldc.org/Loaddata.aspx?mode=22/01/2021
# https://www.delhisldc.org/Loaddata.aspx?mode=23/01/2021
# https://www.delhisldc.org/Loaddata.aspx?mode=24/01/2021
# https://www.delhisldc.org/Loaddata.aspx?mode=25/01/2021
# https://www.delhisldc.org/Loaddata.aspx?mode=26/01/2021
# https://www.delhisldc.org/Loaddata.aspx?mode=27/01/2021
# https://www.delhisldc.org/Loaddata.aspx?mode=28/01/2021
# https://www.delhisldc.org/Loaddata.aspx?mode=29/01/2021
# https://www.delhisldc.org/Loaddata.aspx?mode=30/01/2021
# ...
